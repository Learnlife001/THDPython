# %% [markdown]
# # Python Primer

# %% [markdown]
# R-1.1

# %%
def is_multiple(n, m):
    if (m % n == 0):
        return True
    else:
        return False

# %%
#Test
print(is_multiple(2, 4))
print(is_multiple(44,4))
print(is_multiple(44,88))
# Out:
# True
# False
# True

# %% [markdown]
# R-1.2

# %%
def is_even(k):
    return k&1 == 0

# %% [markdown]
# Explanation <br>
#
# & as Bit Operator: <br>
# 0 & 0 = 0 <br>
# 0 & 1 = 0 <br>
# 1 & 0 = 0 <br>
# 1 & 1 = 1 <br>
#
# Number 1 in binary: 0001 <br>
# k & 1 compares only the LAST bit <br>
#
# Example for k=6: <br>
# 6 = 110 <br>
# 1 = 001 <br>
#
# 110 <br>
# & <br>
# 001 <br>
# = <br>
# 000 <br>
#
# --> 6 is even <br>
# (If last digit is 1 --> odd )

# %%
#Test
print(is_even(10))
# Out:
# True

# %% [markdown]
# R-1.3

# %%
def minmax(data):
    min_num = max_num = data[0]

    for num in data[1:]:
        if num < min_num:
            min_num = num
        elif num > max_num:
            max_num = num
    return min_num, max_num

data = [-100, 3, 2, 0, 100]
print(minmax(data))
# Out:
# (-100, 100)

# %% [markdown]
# R-1.4
# Write a short Python function that takes a positive integer n and returns the sum of the squares of all the positive integers smaller than n .

# %%
def sum_squares(n):
    sum = 0
    for i in range(1,n):
        sum += i**2
    return sum
print(sum_squares(3))
# Out:
# 5

# %% [markdown]
# R-1.5 Give a single command that computes the sum from Exercise R-1.4, relying on Python’s comprehension syntax and the built-in sum function.

# %%
def sum_squares_short(n):
    return sum([i**2 for i in range (1,n)])
print(sum_squares_short(3))
# Out:
# 5

# %% [markdown]
# R-1.6 Write a short Python function that takes a positive integer n and returns the sum of the squares of all the odd positive integers smaller than n

# %%
def sum_of_squares_of_odds(n):
    total = 0
    for i in range(1, n, 2):
        total += i * i 
    return total

print(sum_of_squares_of_odds(5))
# Out:
# 10

# %%
def sum_squares_odd(n):
    return sum([i**2 for i in range (1,n) if i%2!=0])
print(sum_squares_odd(10))
# Out:
# 165

# %% [markdown]
# R.1-7 Give a single command that computes the sum from Exercise R-1.6, relying on Python’s comprehension syntax and the built-in sum function.
# --> Already done

# %% [markdown]
# R.1-8 Python allows negative integers to be used as indices into a sequence, such as a string. If string s has length n , and expression s[k] is used for index − n ≤ k < 0, what is the equivalent index j ≥ 0 such that s[j] references the same element?

# %%
def string_index(n, k):
    j = n+k
    return j
print(string_index(6, -2))
# Garden s[-2] = e = s [[4], n=6
# Out:
# 4

# %% [markdown]
# R-1.9 What parameters should be sent to the range constructor, to produce a range with values 50, 60, 70, 80?

# %%
def range1():
    return [i for i in range(50, 81, 10)]

print(range1())
# Out:
# [50, 60, 70, 80]

# %%
def range1():
    for i in range(50, 81, 10):
        print(i)

range1()
# Out:
# 50
# 60
# 70
# 80

# %% [markdown]
# R-1.10 What parameter should be sent to the range constructor, to produce a range with values 8, 6, 4, 2,0,-2, -4,-6,-8?

# %%
def range2():
    for i in range(8, -9, -2):
        print(i)

range2()
# Out:
# 8
# 6
# 4
# 2
# 0
# -2
# -4
# -6
# -8

# %% [markdown]
# R.1-11 Demonstrate how to use Python’s list comprehension syntax to produce the list [1, 2, 4, 8, 16, 32, 64, 128, 256]

# %%
list = [2**i for i in range(9)]
print(list)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256]

# %% [markdown]
# R.1-13 Python’s random module includes a function choice(data) that returns a random element from a non-empty sequence. The random module includes a more basic function randrange , with parameterization similar to the built-in range function, that return a random choice from the given range. Using only the randrange function, implement your own version of the choice function

# %%
import random

def my_choice(data):
    assert len(data) > 0
    random_index = random.randrange(0, len(data))
    return data[random_index]

# Beispielaufruf
data = [1, 2, 3, 4, 5]
print(my_choice(data))
# Out:
# 1

# %% [markdown]
# Creativity Part

# %% [markdown]
# Write a pseudo-code description of a function that reverses a list of n integers, so that the numbers are listed in the opposite order than they were before, and compare this method to an equivalent Python function for doing the same thing.

# %%
def reverse_list(data):
    n = len(data)
    for i in range(n//2):
        temp = data[i]
        data[i] = data[n - i -1]
        data[n -i -1] = temp
    return data
    
data = [1, 2, 3, 4, 5]
print(reverse_list(data))
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# C-1.24: Write a short Python function that counts the number of vowels in a given character string.

# %%
def count_vowels(s):
    vowels = ['a', 'e', 'i', 'o', 'u', 'A', 'E', 'I', 'O', 'U']
    count = 0
    for letter in s:
        if letter in vowels:
            count += 1
    return count

print(count_vowels('garden'))
# Out:
# 2

# %% [markdown]
# C-1.25: Write a short Python function that takes a string s , representing a sentence, and returns a copy of the string with all punctuation removed. For example, if given the string "Let s try, Mike." , this function would return "Lets try Mike"

# %%
def remove_punctation(s):
    punctations = ['.', ',', ';', ':', '!', '?']
    for punctation in punctations:
        s = s.replace(punctation, '')
    return s

print(remove_punctation('H!ey, ha?ve you..'))
# Out:
# Hey have you

# %% [markdown]
# C-1.28: The p-norm of a vector v = ( v as v = 1 p , v 2 p v 1 , . . . , v + p v 2 n ) in n -dimensional space is deﬁned + · · · + p v n . For the special case of p = 2, this results in the traditional Euclidean norm , which represents the length of the vector. For example, the Euclidean norm of a two-dimensional vector with coordinates ( 4 , √ √ 3 ) has a √ Euclidean norm of 4 2 + 3 2 = 16 + 9 = 25 = 5. Give an implementation of a function named norm such that norm(v, p) returns the p -norm value of v and norm(v) returns the Euclidean norm of v . You may assume that v is a list of numbers.

# %%
def norm(v, p=2):
    p_norm = sum([abs(x)**p for x in v]) ** (1/p)
    return p_norm

v = [4, 3**0.5]
print(norm(v, 5))
print(norm(v))
# Out:
# 4.01210499473677
# 4.358898943540674

# %% [markdown]
# Projects:
# P-1.29: Write a Python program that outputs all possible strings formed by using the characters c , a , t , d , o , and g exactly once.

# %%
from itertools import permutations

def generate_strings():
    characters = 'catdog'
    perms = permutations(characters)
    for perm in perms:
        print(''.join(perm))

generate_strings()
# Out:
# catdog
# catdgo
# catodg
# catogd
# catgdo
# catgod
# cadtog
# cadtgo
# cadotg
# cadogt
# cadgto
# cadgot
# caotdg
# caotgd
# caodtg
# caodgt
# caogtd
# caogdt
# cagtdo
# cagtod
# cagdto
# cagdot
# cagotd
# cagodt
# ctadog
# ctadgo
# ctaodg
# ctaogd
# ctagdo
# ctagod
# ctdaog
# ctdago
# ctdoag
# ctdoga
# ctdgao
# ctdgoa
# ctoadg
# ctoagd
# ctodag
# ctodga
# ctogad
# ctogda
# ctgado
# ctgaod
# ctgdao
# ctgdoa
# ctgoad
# ctgoda
# cdatog
# cdatgo
# cdaotg
# cdaogt
# cdagto
# cdagot
# cdtaog
# cdtago
# cdtoag
# cdtoga
# cdtgao
# cdtgoa
# cdoatg
# cdoagt
# cdotag
# cdotga
# cdogat
# cdogta
# cdgato
# cdgaot
# cdgtao
# cdgtoa
# cdgoat
# cdgota
# coatdg
# coatgd
# coadtg
# coadgt
# coagtd
# coagdt
# cotadg
# cotagd
# cotdag
# cotdga
# cotgad
# cotgda
# codatg
# codagt
# codtag
# codtga
# codgat
# codgta
# cogatd
# cogadt
# cogtad
# cogtda
# cogdat
# cogdta
# cgatdo
# cgatod
# cgadto
# cgadot
# cgaotd
# cgaodt
# cgtado
# cgtaod
# cgtdao
# cgtdoa
# cgtoad
# cgtoda
# cgdato
# cgdaot
# cgdtao
# ...

# %% [markdown]
# P-1.30 Write a Python program that can take a positive integer greater than 2 as input and write out the number of times one must repeatedly divide this number by 2 before getting a value less than 2.

# %%
def count_divisions(n):
    if n <= 2:
        return
    
    count = 0
    while n >= 2:
        n /= 2
        count += 1
    
    return count

count_divisions(10)
# Out:
# 3

# %% [markdown]
# P-1.35 The birthday paradox says that the probability that two people in a room will have the same birthday is more than half, provided n, the number of people in the room, is more than 23. This property is not really a paradox, but many people find it surprising. Design a Python program that can test this paradox by a series of experiments on randomly generated birthdays, which test this paradox for n = 5,10,15,20,...,100.

# %%
import random

def simulate_birthday_paradox(num_people, trials=1000):
    successful_trials = 0
    for _ in range(trials):
        birthdays = [random.randint(1, 365) for _ in range(num_people)]
        if len(birthdays) != len(set(birthdays)): 
            #checks if there are any duplicate birthdays. 
            # A set in Python does not allow duplicates, so converting the list birthdays 
            # to a set removes any duplicates
            # If the length of the set is less than the list, it means at least one birthday is shared
            successful_trials += 1
    
    probability = successful_trials / trials
    return probability

def main():
    for num_people in range(5, 101, 5):
        probability = simulate_birthday_paradox(num_people)
        print(f"With {num_people} people the probability for at least two same birthdays is: {probability:.2f}")

main()
# Out:
# With 5 people the probability for at least two same birthdays is: 0.01
# With 10 people the probability for at least two same birthdays is: 0.11
# With 15 people the probability for at least two same birthdays is: 0.26
# With 20 people the probability for at least two same birthdays is: 0.42
# With 25 people the probability for at least two same birthdays is: 0.57
# With 30 people the probability for at least two same birthdays is: 0.68
# With 35 people the probability for at least two same birthdays is: 0.84
# With 40 people the probability for at least two same birthdays is: 0.92
# With 45 people the probability for at least two same birthdays is: 0.95
# With 50 people the probability for at least two same birthdays is: 0.97
# With 55 people the probability for at least two same birthdays is: 0.99
# With 60 people the probability for at least two same birthdays is: 1.00
# With 65 people the probability for at least two same birthdays is: 0.99
# ...

# %% [markdown]
# P-1.36 Write a Python program that inputs a list of words, separated by whitespace, and outputs how many times each word appears in the list. You need not worry about efficiency at this point, however, as this topic is something that will be addressed later in this book.

# %%
def count_words():
    text = input("Enter a list of words separated by spaces: ")
    words = text.split()
    word_count = {} #dictionary with key=word and value=count
    
    for word in words:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1
    
    for word, count in word_count.items():
        print(f"The word '{word}' appears {count} times.")
        
count_words()
# Out:
# The word 'hi' appears 3 times.
# The word 'hello' appears 1 times.
# The word 'hey' appears 1 times.

# %% [markdown]
# # Problem 6.3

# %% [markdown]
#  Consider a circle inscribed in a unit square. Given that the circle and the square have a ratio of areas
#  that is 4, the value of can be approximated using a Monte Carlo method:
#  1. Draw a square, then inscribe a circle within it.
#  2. Uniformly scatter objects of uniform size over the square.
#  3. Count the number of objects inside the circle and the total number of objects.
#  4. The ratio of the two counts is an estimate of the ratio of the two areas, which is 4. Multiply the
#  result by 4 to estimate .
#  Implement this Monte Carlo method and run it for a varying number (e.g. 100, 1000, 10000, 100000,
#  ...) of objects. Compare your results to the actual value of (math.pi).

# %%
import random
import math
def calculate_pi(n):
    circle_count = 0
    for i in range(n):
        x = random.uniform(0, 1)
        y = random.uniform(0, 1)
        if x**2 + y**2 <= 1: #überprüft ob ein Punkt (x, y) innerhalb des Einheitskreises liegt
            circle_count += 1
    return abs(math.pi -(circle_count / n) * 4)

n_list = [100, 1000, 10000, 100000, 1000000]

for number in n_list:
    print(calculate_pi(number))
# Out:
# 0.018407346410207026
# 0.018407346410207026
# 0.013992653589792958
# 0.008712653589793007
# 0.0005033464102068841
